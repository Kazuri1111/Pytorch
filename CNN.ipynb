# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
import pickle

# %%
transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor(), torchvision.transforms.Normalize((0.5,),(0.5,))])
train_set = torchvision.datasets.MNIST(root="MNIST", train=True, download=True, transform=transform)
test_set = torchvision.datasets.MNIST(root="MNIST", train=False, download=True, transform=transform)
train_loader = DataLoader(train_set, batch_size=64, shuffle=True, num_workers=2)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False, num_workers=2)

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(2, stride=2)
        self.conv1 = nn.Conv2d(1,16,3)
        self.conv2 = nn.Conv2d(16,32,3)
        self.func1 = nn.Linear(32*5*5, 120)
        self.func2 = nn.Linear(120,10)

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.pool(x)
        x = x.view(x.size()[0], -1)
        x = self.func1(x)
        x = self.relu(x)
        x = self.func2(x)
        return x

# %%
model = CNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=0.005)

# %%
losses = []
for epoch in range(100):
    model.train()
    for batch in train_loader:
        optimizer.zero_grad()
        prediction = model(batch[0])
        loss = criterion(prediction, batch[1])
        train_loss = loss.item()
        losses.append(train_loss)
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+1} | train_loss:{train_loss}")

    for batch in test_loader:
        optimizer.zero_grad()
        prediction = model(batch[0])
        loss = criterion(prediction, batch[1])
        loss.backward()
        optimizer.step()
# Out:
# Epoch 1 | train_loss:0.3957759737968445
# Epoch 2 | train_loss:0.11211442947387695
# Epoch 3 | train_loss:0.09716687351465225
# Epoch 4 | train_loss:0.07155212014913559
# Epoch 5 | train_loss:0.09079495072364807
# Epoch 6 | train_loss:0.03388676047325134
# Epoch 7 | train_loss:0.030975086614489555
# Epoch 8 | train_loss:0.0330594927072525
# Epoch 9 | train_loss:0.04112349823117256
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 11
#       9     losses.append(train_loss)
#      10     loss.backward()
# ---> 11     optimizer.step()
#      12 print(f"Epoch {epoch+1} | train_loss:{train_loss}")
#      14 for batch in test_loader:
#
# File ~/mambaforge/envs/torchenv/lib/python3.10/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File ~/mambaforge/envs/torchenv/lib/python3.10/site-packages/torch/optim/optimizer.py:33, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      31 try:
#      32     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 33     ret = func(self, *args, **kwargs)
#      34 finally:
#      35     torch.set_grad_enabled(prev_grad)
#
# File ~/mambaforge/envs/torchenv/lib/python3.10/site-packages/torch/optim/sgd.py:76, in SGD.step(self, closure)
#      72 momentum_buffer_list = []
#      74 has_sparse_grad = self._init_group(group, params_with_grad, d_p_list, momentum_buffer_list)
# ---> 76 sgd(params_with_grad,
#      77     d_p_list,
#      78     momentum_buffer_list,
#      79     weight_decay=group['weight_decay'],
#      80     momentum=group['momentum'],
#      81     lr=group['lr'],
#      82     dampening=group['dampening'],
#      83     nesterov=group['nesterov'],
#      84     maximize=group['maximize'],
#      85     has_sparse_grad=has_sparse_grad,
#      86     foreach=group['foreach'])
#      88 # update momentum_buffers in state
#      89 for p, momentum_buffer in zip(params_with_grad, momentum_buffer_list):
#
# File ~/mambaforge/envs/torchenv/lib/python3.10/site-packages/torch/optim/sgd.py:222, in sgd(params, d_p_list, momentum_buffer_list, has_sparse_grad, foreach, weight_decay, momentum, lr, dampening, nesterov, maximize)
#     219 else:
#     220     func = _single_tensor_sgd
# --> 222 func(params,
#     223      d_p_list,
#     224      momentum_buffer_list,
#     225      weight_decay=weight_decay,
#     226      momentum=momentum,
#     227      lr=lr,
#     228      dampening=dampening,
#     229      nesterov=nesterov,
#     230      has_sparse_grad=has_sparse_grad,
#     231      maximize=maximize)
#
# File ~/mambaforge/envs/torchenv/lib/python3.10/site-packages/torch/optim/sgd.py:265, in _single_tensor_sgd(params, d_p_list, momentum_buffer_list, weight_decay, momentum, lr, dampening, nesterov, maximize, has_sparse_grad)
#     262     else:
#     263         d_p = buf
# --> 265 param.add_(d_p, alpha=-lr)
#
# KeyboardInterrupt:

# %%
loss.item()
# Out:
# 0.03193401172757149

# %%
len(losses)
# Out:
# 8617

# %%
with open("CNN_pickle_test", "wb") as f:
    pickle.dump(losses, f)

# %%
with open("CNN_pickle_test", "rb") as f:
    losses_ = pickle.load(f)
losses_
# Out:
# [2.3080503940582275,
#  2.3157994747161865,
#  2.3003084659576416,
#  2.3132882118225098,
#  2.309725284576416,
#  2.3051609992980957,
#  2.286848545074463,
#  2.2963790893554688,
#  2.3126609325408936,
#  2.292819023132324,
#  2.3074519634246826,
#  2.2943153381347656,
#  2.300705671310425,
#  2.2979023456573486,
#  2.300865888595581,
#  2.3078534603118896,
#  2.307793140411377,
#  2.3028671741485596,
#  2.2937521934509277,
#  2.2877390384674072,
#  2.299406051635742,
#  2.2978549003601074,
#  2.2982327938079834,
#  2.2955241203308105,
#  2.2986555099487305,
#  2.296056032180786,
#  2.306704521179199,
#  2.3002476692199707,
#  2.3088271617889404,
#  2.2891926765441895,
#  2.3023080825805664,
#  2.2999343872070312,
#  2.296405076980591,
#  2.2974460124969482,
#  2.3035881519317627,
#  2.293267011642456,
#  2.2919235229492188,
#  2.293144464492798,
#  2.2849910259246826,
#  2.286529064178467,
#  2.2959659099578857,
#  2.285979747772217,
#  2.2795515060424805,
#  2.289767265319824,
#  2.297098159790039,
#  2.292921304702759,
#  2.2956628799438477,
#  2.283576250076294,
#  2.2860772609710693,
#  2.290158748626709,
#  2.2931082248687744,
#  2.2888243198394775,
#  2.293195962905884,
#  2.2873570919036865,
#  2.2902941703796387,
#  2.291262626647949,
#  2.298046588897705,
#  2.292559862136841,
#  2.29958438873291,
#  2.280799150466919,
#  2.283731460571289,
#  2.292996644973755,
#  2.285611391067505,
#  2.279693841934204,
#  2.2919554710388184,
#  2.2883098125457764,
#  2.2897443771362305,
#  2.2893989086151123,
#  2.2856647968292236,
#  2.2868120670318604,
#  2.285857677459717,
#  2.286064624786377,
#  2.2882912158966064,
#  2.3024063110351562,
#  2.279402732849121,
#  2.2806944847106934,
#  2.2796690464019775,
#  2.286402702331543,
#  2.284698724746704,
#  2.2928435802459717,
#  2.2816529273986816,
#  2.2864787578582764,
#  2.2951488494873047,
#  2.2810654640197754,
#  1.4521559476852417,
#  1.477500319480896,
#  1.5040591955184937,
#  1.3819072246551514,
#  1.4857009649276733,
#  1.2973777055740356,
#  1.352165699005127,
#  1.327954649925232,
#  1.3580970764160156,
#  1.3844712972640991,
#  1.4819703102111816,
#  1.4812675714492798,
#  1.3256419897079468,
#  1.333881139755249,
#  1.313431739807129,
#  1.3854392766952515,
#  1.3387466669082642,
#  1.2801547050476074,
#  1.2764620780944824,
#  1.177914023399353,
#  1.2970478534698486,
#  1.3754568099975586,
#  1.1322972774505615,
#  1.4388728141784668,
#  1.242332935333252,
#  1.3197399377822876,
#  1.2626413106918335,
#  1.295967936515808,
#  1.201212763786316,
#  1.1179792881011963,
#  1.1528568267822266,
#  1.2796919345855713,
#  1.193137526512146,
#  1.1412967443466187,
#  1.1283352375030518,
#  1.0880305767059326,
#  1.148611068725586,
#  1.1550531387329102,
#  1.2304388284683228,
#  1.097273349761963,
#  1.1081750392913818,
#  1.0649704933166504,
#  1.0830960273742676,
#  1.2594245672225952,
#  1.1352989673614502,
#  1.184011459350586,
#  1.0894103050231934,
#  1.1641815900802612,
#  1.0510177612304688,
#  1.0325853824615479,
#  1.0681663751602173,
#  1.0751667022705078,
#  1.0247740745544434,
#  0.9505981802940369,
#  1.1087011098861694,
#  1.038068413734436,
#  0.9826647639274597,
#  1.0763916969299316,
#  0.9299934506416321,
#  0.9149876236915588,
#  1.046143889427185,
#  1.0409507751464844,
#  0.9883505702018738,
#  1.0902292728424072,
#  0.9860802888870239,
#  1.0402871370315552,
#  0.8056767582893372,
#  0.8747271299362183,
#  0.9512636065483093,
#  0.9327510595321655,
#  1.0631860494613647,
#  0.9667535424232483,
#  1.0615818500518799,
#  0.9371739625930786,
#  0.9876806139945984,
#  0.8713477253913879,
#  0.9207590818405151,
#  0.889650821685791,
#  0.9423067569732666,
#  0.919384241104126,
#  0.6615755558013916,
#  0.8562130331993103,
#  0.7390024065971375,
#  0.8725396990776062,
#  0.8864096403121948,
#  1.0203303098678589,
#  0.9388355612754822,
#  0.780003547668457,
#  0.8048562407493591,
#  0.7808364033699036,
#  0.7129083871841431,
#  0.7591463327407837,
#  0.8595193028450012,
#  0.7890967130661011,
#  0.852353036403656,
#  0.7614383697509766,
#  0.8941317796707153,
#  0.80165034532547,
#  0.8313809037208557,
#  0.7721649408340454,
#  0.7132882475852966,
#  0.6741436123847961,
#  0.741234540939331,
#  0.8118084669113159,
#  0.7454802393913269,
#  0.7825903296470642,
#  0.7286150455474854,
#  0.6179526448249817,
#  0.6577044129371643,
#  0.6798245906829834,
#  0.9040396213531494,
#  0.8479149341583252,
#  0.8468539714813232,
#  0.730819046497345,
#  0.6785419583320618,
#  0.6591326594352722,
#  0.7190200090408325,
#  0.7162795662879944,
#  0.8140468597412109,
#  0.6809037327766418,
#  0.643524169921875,
#  0.7050294280052185,
#  0.7595260739326477,
#  0.7440668344497681,
#  0.8362611532211304,
#  0.7447978854179382,
#  0.6705207228660583,
#  0.7307013869285583,
#  0.7424511909484863,
#  0.6183735728263855,
#  0.661052942276001,
#  0.7116701602935791,
#  0.5993049144744873,
#  0.4815594255924225,
#  0.5624112486839294,
#  0.7115886807441711,
#  0.6202749609947205,
#  0.66877681016922,
#  0.6721549034118652,
#  0.7551863789558411,
#  0.6153793931007385,
#  0.6753458976745605,
#  0.7629898190498352,
#  0.7301960587501526,
#  0.5671047568321228,
#  0.526984691619873,
#  0.5952730178833008,
#  0.6402581930160522,
#  0.6535084247589111,
#  0.5908207297325134,
#  0.6254151463508606,
#  0.5906141996383667,
#  0.8645755052566528,
#  0.4624403119087219,
#  0.7095917463302612,
#  0.6115069389343262,
#  0.5877086520195007,
#  0.6291348338127136,
#  0.655599057674408,
#  0.5323892831802368,
#  0.5841071605682373,
#  0.5340087413787842,
#  0.4186073839664459,
#  0.5611913800239563,
#  0.7072763442993164,
#  0.7183464765548706,
#  0.643707811832428,
#  0.5810509920120239,
#  0.4515622854232788,
#  0.6430453658103943,
#  0.5116485357284546,
#  0.5585667490959167,
#  0.6017412543296814,
#  0.5012685656547546,
#  0.4509132206439972,
#  0.5383073091506958,
#  0.685653805732727,
#  0.728671133518219,
#  0.6346167922019958,
#  0.7576115131378174,
#  0.6594265103340149,
#  0.6895267963409424,
#  0.5958660244941711,
#  0.5203650593757629,
#  0.5682548880577087,
#  0.6492096781730652,
#  0.5309407114982605,
#  0.6635346412658691,
#  0.715164840221405,
#  0.7454047203063965,
#  0.6143301129341125,
#  0.6199281215667725,
#  0.6734649538993835,
#  0.5015072822570801,
#  0.6577853560447693,
#  0.4987684488296509,
#  0.8120418190956116,
#  0.567061722278595,
#  0.4566442370414734,
#  0.552295446395874,
#  0.6041684150695801,
#  0.5331592559814453,
#  0.6251775622367859,
#  0.520494282245636,
#  0.5825620889663696,
#  0.760340690612793,
#  0.7215068340301514,
#  0.7773394584655762,
#  0.4873011112213135,
#  0.45926612615585327,
#  0.4338735044002533,
#  0.5031360983848572,
#  0.527515172958374,
#  0.6986991763114929,
#  0.47302308678627014,
#  0.4656563699245453,
#  0.6842182278633118,
#  0.4356755018234253,
#  0.5959150195121765,
#  0.6477107405662537,
#  0.6753406524658203,
#  0.5204795002937317,
#  0.5113424062728882,
#  0.5136650204658508,
#  0.5482239723205566,
#  0.42345067858695984,
#  0.5165523290634155,
#  0.537528932094574,
#  0.5564532279968262,
#  0.6207094788551331,
#  0.6052907109260559,
#  0.4963819682598114,
#  0.7124525904655457,
#  0.6331276893615723,
#  0.6773720383644104,
#  0.35092371702194214,
#  0.444497287273407,
#  0.43471869826316833,
#  0.4589804708957672,
#  0.4368806481361389,
#  0.5651389360427856,
#  0.3312820494174957,
#  0.4488998353481293,
#  0.4063282907009125,
#  0.4053676128387451,
#  0.5931430459022522,
#  0.4997338354587555,
#  0.6518244743347168,
#  0.5892763733863831,
#  0.6219531297683716,
#  0.5501601696014404,
#  0.6150508522987366,
#  0.5501394867897034,
#  0.44069015979766846,
#  0.45659348368644714,
#  0.3293197453022003,
#  0.4672251343727112,
#  0.5285101532936096,
#  0.6096287369728088,
#  0.4099326431751251,
#  0.33702248334884644,
#  0.4566842019557953,
#  0.39081546664237976,
#  0.4392809569835663,
#  0.38357940316200256,
#  0.47909149527549744,
#  0.6084299087524414,
#  0.36831364035606384,
#  0.595878005027771,
#  0.4831831455230713,
#  0.5046615600585938,
#  0.4516615569591522,
#  0.4448630213737488,
#  0.42271122336387634,
#  0.5115927457809448,
#  0.4775058627128601,
#  0.4879935681819916,
#  0.3730944097042084,
#  0.33156517148017883,
#  0.3930288255214691,
#  0.4431036114692688,
#  0.4046056568622589,
#  0.3321972191333771,
#  0.40227651596069336,
#  0.4121047258377075,
#  0.5738036632537842,
#  0.5550829768180847,
#  0.4612695574760437,
#  0.4272639751434326,
#  0.3435029089450836,
#  0.4970830976963043,
#  0.4374682307243347,
#  0.5698779821395874,
#  0.4037756323814392,
#  0.4979311525821686,
#  0.33956578373908997,
#  0.4842812418937683,
#  0.4107379615306854,
#  0.30024850368499756,
#  0.4481334388256073,
#  0.4450675845146179,
#  0.36680951714515686,
#  0.37457332015037537,
#  0.33842673897743225,
#  0.5150094628334045,
#  0.402974933385849,
#  0.41487184166908264,
#  0.5000039935112,
#  0.4999947249889374,
#  0.5494369864463806,
#  0.3397325277328491,
#  0.5643613338470459,
#  0.4145585596561432,
#  0.49912771582603455,
#  0.5430750846862793,
#  0.46546822786331177,
#  0.4351029694080353,
#  0.3224635720252991,
#  0.37364518642425537,
#  0.4211535155773163,
#  0.3372950851917267,
#  0.63229900598526,
#  0.43950387835502625,
#  0.3355632722377777,
#  0.2956506311893463,
#  0.2969479262828827,
#  0.358373761177063,
#  0.3442440927028656,
#  0.540472686290741,
#  0.41003480553627014,
#  0.45402297377586365,
#  0.44050532579421997,
#  0.3016534447669983,
#  0.3349206745624542,
#  0.552645742893219,
#  0.40067601203918457,
#  0.48254454135894775,
#  0.3163364827632904,
#  0.4316914677619934,
#  0.25280308723449707,
#  0.6045509576797485,
#  0.39413198828697205,
#  0.39703816175460815,
#  0.4543306529521942,
#  0.2669679522514343,
#  0.3039777874946594,
#  0.3209630846977234,
#  0.41092368960380554,
#  0.30359962582588196,
#  0.46906808018684387,
#  0.43036794662475586,
#  0.35223379731178284,
#  0.4045444428920746,
#  0.4071936011314392,
#  0.42058065533638,
#  0.3774546682834625,
#  0.4357813000679016,
#  0.45406174659729004,
#  0.44283413887023926,
#  0.4060668349266052,
#  0.4095413088798523,
#  0.4787788987159729,
#  0.6811845898628235,
#  0.40098267793655396,
#  0.37497857213020325,
#  0.4232659339904785,
#  0.39730599522590637,
#  0.3388069272041321,
#  0.44480738043785095,
#  0.39362338185310364,
#  0.3956395089626312,
#  0.8464371562004089,
#  0.2886800467967987,
#  0.33358705043792725,
#  0.4517359137535095,
#  0.4691513478755951,
#  0.41233086585998535,
#  0.3469008207321167,
#  0.305147647857666,
#  0.2768692374229431,
#  0.3135969042778015,
#  0.36936724185943604,
#  0.3633125424385071,
#  0.4029271900653839,
#  0.45009365677833557,
#  0.34859299659729004,
#  0.46587157249450684,
#  0.4284273684024811,
#  0.3295275568962097,
#  0.5333828926086426,
#  0.39100340008735657,
#  0.2725925147533417,
#  0.4329901337623596,
#  0.4501126706600189,
#  0.48044663667678833,
#  0.2638586759567261,
#  0.260355681180954,
#  0.5620935559272766,
#  0.3268338143825531,
#  0.195242777466774,
#  0.3619502782821655,
#  0.5223271250724792,
#  0.22510123252868652,
#  0.45791810750961304,
#  0.45730748772621155,
#  0.2884952127933502,
#  0.4512955844402313,
#  0.38633301854133606,
#  0.32569342851638794,
#  0.29999494552612305,
#  0.4172489643096924,
#  0.4354690909385681,
#  0.30697521567344666,
#  0.33979320526123047,
#  0.33544525504112244,
#  0.3521125316619873,
#  0.537122905254364,
#  0.36358898878097534,
#  0.3523361384868622,
#  0.34071600437164307,
#  0.40962091088294983,
#  0.33262214064598083,
#  0.41124945878982544,
#  0.6750087141990662,
#  0.36706599593162537,
#  0.4868885576725006,
#  0.5484293699264526,
#  0.3147256672382355,
#  0.3967072665691376,
#  0.3384057879447937,
#  0.3554691970348358,
#  0.3125263452529907,
#  0.4519573748111725,
#  0.35473954677581787,
#  0.21259598433971405,
#  0.42822375893592834,
#  0.4444630444049835,
#  0.30415597558021545,
#  0.4577065706253052,
#  0.3171676695346832,
#  0.4760984182357788,
#  0.4652639925479889,
#  0.4975482225418091,
#  0.30296364426612854,
#  0.43559592962265015,
#  0.4083733558654785,
#  0.3058635890483856,
#  0.47452616691589355,
#  0.45320117473602295,
#  0.2800779938697815,
#  0.48650333285331726,
#  0.37803828716278076,
#  0.3259545564651489,
#  0.3235562741756439,
#  0.3957759737968445,
#  0.24353653192520142,
#  0.334989070892334,
#  0.3041824996471405,
#  0.24312682449817657,
#  0.43013569712638855,
#  0.4342002272605896,
#  0.2872844934463501,
#  0.4409834146499634,
#  0.2722349166870117,
#  0.2863214313983917,
#  0.2568998634815216,
#  0.3804217278957367,
#  0.33749720454216003,
#  0.4128994345664978,
#  0.3897863030433655,
#  0.3885619342327118,
#  0.2527467906475067,
#  0.26835280656814575,
#  0.17725463211536407,
#  0.26149842143058777,
#  0.368865042924881,
#  0.4431403577327728,
#  0.49429237842559814,
#  0.3111158013343811,
#  0.1780870258808136,
#  0.20432966947555542,
#  0.27087584137916565,
#  0.59988933801651,
#  0.390412837266922,
#  0.2324921041727066,
#  0.4830809235572815,
#  0.17952246963977814,
#  0.3516000807285309,
#  0.2613600492477417,
#  0.3293488025665283,
#  0.28403520584106445,
#  0.35260316729545593,
#  0.3768113851547241,
#  0.4155530631542206,
#  0.2306281477212906,
#  0.27068325877189636,
#  0.2885240316390991,
#  0.2913217842578888,
#  0.3247724771499634,
#  0.2413717657327652,
#  0.3741515576839447,
#  0.2533261775970459,
#  0.39756134152412415,
#  0.31396183371543884,
#  0.2400588095188141,
#  0.310903936624527,
#  0.3035530745983124,
#  0.3083939552307129,
#  0.415625661611557,
#  0.2237270623445511,
#  0.30484580993652344,
#  0.342477947473526,
#  0.21439792215824127,
#  0.2634241282939911,
#  0.3658931851387024,
#  0.17378604412078857,
#  0.2207171469926834,
#  ...]
